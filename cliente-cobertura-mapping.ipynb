# %% [markdown]
# # Inteligencia de Negocios Geoespacial en Python
#
# > Proyecto en Python que integra inteligencia artificial, geocodificación y análisis geoespacial para mejorar direcciones, obtener coordenadas y asignar clientes automáticamente a oficinas según su ubicación.
#
# ## Funcionalidades:
# - ✨ Mejora de direcciones con **Google Gemini**
# - 📍 Geocodificación con **OpenRouteService**
# - 🗺️ Asignación automática a oficinas usando **GeoJSON**
# - 📊 Visualización interactiva con **Folium**
# - 📁 Salida en Excel con estado de cobertura
#
# ## Archivos requeridos:
# - `clientes.xlsx`: Datos de entrada con columnas: Departamento, Provincia, Distrito, Dirección
# - `cercos.geojson`: Polígonos de cobertura con propiedad `"name"`

# %% [markdown]
# ### 🧰 Instalar dependencias
#
# Solo se necesita ejecutar una vez.
# ### Ejecutar solo si no están instaladas
# ```python
# > pip install pandas openrouteservice google-generativeai folium geopandas shapely openpyxl
# ```
# ### 🚀Importar Librerias Necesarias

# %%
import pandas as pd
import google.generativeai as genai
import openrouteservice
import json
import folium
from shapely.geometry import Point, shape
from openpyxl import load_workbook
import time

# %% [markdown]
# ### 🔑 Configuración de APIs

# %%
# Gemini API
genai.configure(api_key="API GEMINI")
gemini_model = genai.GenerativeModel("gemini-1.5-flash-latest")

# OpenRouteService API
ors_client = openrouteservice.Client(key="API OPEN ROUTE SERVICE s")

# %% [markdown]
# ### 📂 Cargar datos desde Excel
#
# El archivo debe tener las siguientes columnas:
# - Departamento
# - Provincia
# - Distrito
# - Direccion

# %%
file_path = "clientes.xlsx"
df = pd.read_excel(file_path)

df.head()
# Out:
#   Departamento Provincia   Distrito        Direccion
# 0        Piura     Piura   Morropon      huaylas 110
# 1     Chiclayo  Chiclayo       Laos     cal Real 220
# 2     Chiclayo  Chiclayo       Eten  Jr. Amsznas 440
# 3      Iquitos    Maynas      Belen   Calle Uros 770
# 4        Tacna     Tacna  Candarave  av Salvvrry 300

# %% [markdown]
# ### 🧹 Mejorar direcciones con Gemini
#
# Usamos IA para corregir errores tipográficos y estandarizar direcciones.

# %%
import time

def mejorar_direccion(direccion):
    prompt = f"""
    Estandariza esta dirección peruana:
    - Usa mayúscula solo donde sea necesario
    - Añade el tipo de vía (Av., Jr., Calle, etc.) si no está claro
    - Devuelve SOLO la dirección mejorada, sin explicaciones adicionales
    
    Dirección: {direccion}
    """
    for i in range(3): 
        try:
            response = gemini_model.generate_content(prompt)
            time.sleep(5) 
            return response.text.strip()
        except Exception as e:
            print(f"⚠️ Intento {i+1} fallido para '{direccion}': {e}")
            time.sleep(10) 

    print(f"❌ No se pudo mejorar '{direccion}' después de varios intentos")
    return direccion

# %%
print("🔍 Mejorando direcciones con Gemini...")
df["Direccion"] = df["Direccion"].apply(mejorar_direccion)
# Out:
# 🔍 Mejorando direcciones con Gemini...

# %%
df.head()
# Out:
#   Departamento Provincia   Distrito          Direccion
# 0        Piura     Piura   Morropon  Calle Huaylas 110
# 1     Chiclayo  Chiclayo       Laos     Calle Real 220
# 2     Chiclayo  Chiclayo       Eten   Jr. Amazonas 440
# 3      Iquitos    Maynas      Belen     Calle Uros 770
# 4        Tacna     Tacna  Candarave  Av. Salaverry 300

# %% [markdown]
# ### 📍 Generar dirección completa
#
# Para mejorar precisión de geocodificador.

# %%
df["DireccionCompleta"] = (
    df["Direccion"] + ", " +
    df["Distrito"] + ", " +
    df["Provincia"] + ", " +
    df["Departamento"] + ", Perú"
)

df[["Direccion", "Distrito", "Provincia", "Departamento", "DireccionCompleta"]].head()
# Out:
#            Direccion   Distrito Provincia Departamento  \
# 0  Calle Huaylas 110   Morropon     Piura        Piura
# 1     Calle Real 220       Laos  Chiclayo     Chiclayo
# 2   Jr. Amazonas 440       Eten  Chiclayo     Chiclayo
# 3     Calle Uros 770      Belen    Maynas      Iquitos
# 4  Av. Salaverry 300  Candarave     Tacna        Tacna
#
#                                   DireccionCompleta
# 0   Calle Huaylas 110, Morropon, Piura, Piura, Perú
# 1    Calle Real 220, Laos, Chiclayo, Chiclayo, Perú
# 2  Jr. Amazonas 440, Eten, Chiclayo, Chiclayo, Perú
# 3      Calle Uros 770, Belen, Maynas, Iquitos, Perú
# 4  Av. Salaverry 300, Candarave, Tacna, Tacna, Perú

# %% [markdown]
# ### 🌏 Geocodificación con OpenRouteService

# %%
def get_coordinates(address):
    try:
        response = ors_client.pelias_search(address)
        if response and "features" in response and response["features"]:
            coords = response["features"][0]["geometry"]["coordinates"]
            lat, lon = coords[1], coords[0]
            return round(lat, 6), round(lon, 6)
    except Exception as e:
        print(f"❌ Error con '{address}': {e}")
    return "", ""

df[["Latitud", "Longitud"]] = df["DireccionCompleta"].apply(
    lambda x: pd.Series(get_coordinates(x))
)

# %%
print("📍 Obteniendo coordenadas con OpenRouteService...")
df[["Latitud", "Longitud"]] = df["DireccionCompleta"].apply(
    lambda x: pd.Series(get_coordinates(x))
)
# Out:
# 📍 Obteniendo coordenadas con OpenRouteService...

# %%
df.head()
# Out:
#   Departamento Provincia   Distrito          Direccion  \
# 0        Piura     Piura   Morropon  Calle Huaylas 110
# 1     Chiclayo  Chiclayo       Laos     Calle Real 220
# 2     Chiclayo  Chiclayo       Eten   Jr. Amazonas 440
# 3      Iquitos    Maynas      Belen     Calle Uros 770
# 4        Tacna     Tacna  Candarave  Av. Salaverry 300
#
#                                   DireccionCompleta    Latitud    Longitud
# 0   Calle Huaylas 110, Morropon, Piura, Piura, Perú  -9.518057  -77.531457
# 1    Calle Real 220, Laos, Chiclayo, Chiclayo, Perú  21.073798 -101.621089
# 2  Jr. Amazonas 440, Eten, Chiclayo, Chiclayo, Perú  -6.771557  -79.847250
# 3      Calle Uros 770, Belen, Maynas, Iquitos, Perú  -2.690076  -74.000903
# 4  Av. Salaverry 300, Candarave, Tacna, Tacna, Perú -12.097018  -77.055646

# %% [markdown]
# ### 🧱 Validar si los puntos caen dentro de un polígono (GeoJSON)
#
# Se usa Shapely para validar si un punto está dentro de un polígono.

# %%
geojson_path = "cercos.geojson"

with open(geojson_path, encoding="utf-8") as f:
    geojson_data = json.load(f)

# %%
def encontrar_oficina(lat, lon):
    if pd.isna(lat) or pd.isna(lon):
        return "Sin cobertura"
    
    point = Point(lon, lat) 

    for feature in geojson_data["features"]:
        polygon = shape(feature["geometry"])
        if polygon.contains(point):
            return feature["properties"]["name"]
    return "Sin cobertura"


df["Cobertura"] = df.apply(lambda row: encontrar_oficina(row["Latitud"], row["Longitud"]), axis=1)

# %% [markdown]
# ### 📄 Exportar resultados a Excel

# %%
output_file = "clientes_con_cobertura.xlsx"
df.to_excel(output_file, index=False, engine="openpyxl")

print(f"✅ Archivo guardado como '{output_file}'")
print("\n📊 Resumen:")
print(df["Cobertura"].value_counts())
# Out:
# ✅ Archivo guardado como 'clientes_con_cobertura.xlsx'
#
# 📊 Resumen:
# Cobertura
# Sin cobertura     33
# Oficina Norte     16
# Oficina Sur        9
# Oficina Centro     2
# Name: count, dtype: int64

# %% [markdown]
# ### 🌍 Mapa interactivo con Folium
#
# Muestra los clientes y los cercos definidos en el archivo GeoJSON.

# %%
m = folium.Map(location=[-9.19, -75.0152], zoom_start=5)
folium.GeoJson(geojson_data, name="Cercos").add_to(m)

colores_oficinas = {
    "Oficina Norte": "blue",
    "Oficina Centro": "green",
    "Oficina Sur": "red",
    "Sin cobertura": "gray"
}

for idx, row in df.iterrows():
    lat = row["Latitud"]
    lon = row["Longitud"]

    if pd.isna(lat) or pd.isna(lon):
        continue

    cobertura = row["Cobertura"]
    color = colores_oficinas.get(cobertura, "black")
    popup_text = f"{row['Direccion']}<br>{cobertura}"

    folium.Marker(
        location=[lat, lon],
        icon=folium.Icon(color=color),
        popup=popup_text
    ).add_to(m)

map_file = "mapa_cobertura.html"
m.save(map_file)
print(f"✅ Mapa guardado como '{map_file}'")
# Out:
# ✅ Mapa guardado como 'mapa_cobertura.html'

# %%
from IPython.display import display
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04c8340063277e99b3bbd26ce3541978 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04c8340063277e99b3bbd26ce3541978&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04c8340063277e99b3bbd26ce3541978 = L.map(
#                 &quot;map_04c8340063277e99b3bbd26ce3541978&quot;,
#                 {
#                     center: [-9.19, -75.0152],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4987f5cb4c5388532fd955cab00fafbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4987f5cb4c5388532fd955cab00fafbb.addTo(map_04c8340063277e99b3bbd26ce3541978);
#
#
#
#         function geo_json_db4fe854f05f312fd87607d67d555a9b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_db4fe854f05f312fd87607d67d555a9b = L.geoJson(null, {
#                 onEachFeature: geo_json_db4fe854f05f312fd87607d67d555a9b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_db4fe854f05f312fd87607d67d555a9b_add (data) {
#             geo_json_db4fe854f05f312fd87607d67d555a9b
#                 .addData(data);
#         }
#             geo_json_db4fe854f05f312fd87607d67d555a9b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.7068444, -16.0624369, 0], [-72.2973596, -16.2471059, 0], [-72.2369348, -16.5501136, 0], [-72.4017297, -16.7264298, 0], [-72.2753869, -16.8657885, 0], [-72.0721399, -17.0339338, 0], [-71.8853723, -17.1258245, 0], [-71.5750085, -17.246526, 0], [-71.4431726, -17.3356894, 0], [-71.3333093, -17.6997584, 0], [-70.9378015, -17.9141882, 0], [-70.4241906, -18.2692553, 0], [-70.0400468, -18.1789875, 0], [-69.8912026, -17.5335171, 0], [-69.7595178, -17.3881183, 0], [-69.5762701, -17.0591842, 0], [-69.4708629, -16.4496744, 0], [-69.4280321, -15.2067761, 0], [-69.8380867, -14.5242208, 0], [-70.1958688, -14.2779657, 0], [-70.6411706, -14.318408, 0], [-71.2510368, -15.4312067, 0], [-71.7068444, -16.0624369, 0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;fill&quot;: &quot;#e65100&quot;, &quot;fill-opacity&quot;: 0.30196078431372547, &quot;name&quot;: &quot;Oficina Sur&quot;, &quot;stroke&quot;: &quot;#e65100&quot;, &quot;stroke-opacity&quot;: 1, &quot;stroke-width&quot;: 1.2, &quot;styleUrl&quot;: &quot;#poly-E65100-1200-77-nodesc&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.1349695, -10.000543, 0], [-77.6515711, -11.2961704, 0], [-77.113241, -12.1030191, 0], [-76.3002527, -13.3247267, 0], [-76.2672938, -14.1571264, 0], [-75.1247156, -15.4635181, 0], [-74.8830164, -15.5164545, 0], [-74.7511805, -14.8272381, 0], [-74.3227137, -14.6572436, 0], [-74.5534266, -13.335417, 0], [-76.2782801, -11.6084302, 0], [-76.9045008, -9.8490363, 0], [-77.3878992, -10.1195346, 0], [-78.1349695, -10.000543, 0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;fill&quot;: &quot;#ce93d8&quot;, &quot;fill-opacity&quot;: 0.30196078431372547, &quot;name&quot;: &quot;Oficina Centro&quot;, &quot;stroke&quot;: &quot;#ce93d8&quot;, &quot;stroke-opacity&quot;: 1, &quot;stroke-width&quot;: 1.2, &quot;styleUrl&quot;: &quot;#poly-CE93D8-1200-77-nodesc&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-81.2641555, -4.6963813, 0], [-81.0554152, -5.0138413, 0], [-81.2092238, -5.2217492, 0], [-80.6708938, -5.4842709, 0], [-80.110591, -6.5658929, 0], [-79.7590285, -7.0785925, 0], [-78.4626418, -9.4810795, 0], [-77.2431594, -9.2317559, 0], [-74.1889602, -8.8954326, 0], [-74.2438918, -8.0804903, 0], [-75.9357863, -8.3631986, 0], [-76.0676223, -6.8823045, 0], [-75.3974563, -6.7295798, 0], [-75.6281691, -5.6154888, 0], [-77.6057082, -5.692019, 0], [-78.1440383, -5.8122601, 0], [-78.6274367, -5.1013897, 0], [-79.4623977, -5.1889261, 0], [-80.176509, -4.6087803, 0], [-81.2641555, -4.6963813, 0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;fill&quot;: &quot;#0288d1&quot;, &quot;fill-opacity&quot;: 0.30196078431372547, &quot;name&quot;: &quot;Oficina Norte&quot;, &quot;stroke&quot;: &quot;#0288d1&quot;, &quot;stroke-opacity&quot;: 1, &quot;stroke-width&quot;: 1.2, &quot;styleUrl&quot;: &quot;#poly-0288D1-1200-77-nodesc&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_db4fe854f05f312fd87607d67d555a9b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_db4fe854f05f312fd87607d67d555a9b.addTo(map_04c8340063277e99b3bbd26ce3541978);
#
#
#             var marker_bc9109a97214b176717cdc524bc95eb5 = L.marker(
#                 [-9.518057, -77.531457],
